# %% [markdown]
# # Deidentify/merge data

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports & config

# %%
import datetime
import os
import uuid

import numpy as np
from pandashape import PandaShaper
import pandas as pd

from group_maps.lab_groups import get_lab_group
from group_maps.med_groups import get_is_ibd_med, meds_dict
from group_maps.get_med_group import get_med_group

# %%
data_in_path = './data/'
data_in_registry_path = f'./data/registry/De-identified with linkers 05-15-2020/'
data_in_r3_path = f'./data/r3/R3_1646_BINION_DATA_2020_05_12/'
data_out_path = './out/'

# %%
def merge_project_patient_id(df_left, df_patients, data_source):
    left_column_name = 'STUDY_ID' if data_source == 'r3' else 'AUTO_ID'
    patients_column_name = 'R3_STUDY_ID' if data_source == 'r3' else 'REGISTRY_AUTO_ID'

    df_merged = df_left.merge(df_patients[[patients_column_name, 'PROJECT_PATIENT_ID']], left_on=left_column_name, right_on=patients_column_name, how='left')
    df_merged.drop(columns=[left_column_name, patients_column_name], inplace=True)
    return df_merged

# %% [markdown]
# ## Deidentify/Merge

# %% [markdown]
# ### Patients

# %% [markdown]
# #### Load R3 data

# %%
df_patients_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_DEMOGRAPHICS_2020_05_12.csv')
df_patients_r3.head()
# Out:
#      STUDY_ID  BIRTH_YEAR  DEATH_DATE  GENDER
# 0  6999994666        1958         NaN    MALE
# 1  6999993266        1928  09/24/2017  FEMALE
# 2  6999997423        1958         NaN  FEMALE
# 3  6999947820        1954         NaN  FEMALE
# 4  6999947304        1988         NaN    MALE

# %%
df_patients_r3['DATA_SOURCE'] = 'r3'
df_patients_r3['MARITAL STATUS'] = ''
df_patients_r3['RACE'] = ''
df_patients_r3['ETHNIC_GROUP'] = ''
df_patients_r3['EMPLOYMENT_STATUS'] = ''
df_patients_r3['PATIENT_STATUS'] = df_patients_r3['DEATH_DATE'].apply(lambda x: 'Alive' if x == '' else 'Deceased')
df_patients_r3.drop('DEATH_DATE', axis=1, inplace=True)
df_patients_r3.rename(columns={ 'STUDY_ID': 'R3_STUDY_ID'}, inplace=True)
df_patients_r3.head()
# Out:
#    R3_STUDY_ID  BIRTH_YEAR  GENDER DATA_SOURCE MARITAL STATUS RACE  \
# 0   6999994666        1958    MALE          r3
# 1   6999993266        1928  FEMALE          r3
# 2   6999997423        1958  FEMALE          r3
# 3   6999947820        1954  FEMALE          r3
# 4   6999947304        1988    MALE          r3
#
#   ETHNIC_GROUP EMPLOYMENT_STATUS PATIENT_STATUS
# 0                                      Deceased
# 1                                      Deceased
# 2                                      Deceased
# 3                                      Deceased
# 4                                      Deceased

# %% [markdown]
# #### Load registry data

# %%
df_patients_registry = pd.read_excel(f'{data_in_registry_path}deid_patient_master_2020.xlsx')
df_patients_registry.drop([
    'Unnamed: 0',
    'FYI_FLAG_NAME',
    'ZIP',
    'DATE_FLAG_CREATED',
    'PAT_ID',
    'PAT_MRN_ID'
], axis=1, inplace=True)
df_patients_registry.rename(columns={'AUTO_ID': 'REGISTRY_AUTO_ID'}, inplace=True)
df_patients_registry['DATA_SOURCE'] = 'registry'
df_patients_registry.head()
# Out:
#    REGISTRY_AUTO_ID GENDER  BIRTH_YEAR MARITAL STATUS PATIENT_STATUS  \
# 0                 0      M        1963        Married          Alive
# 1                 1      M        1952        Married          Alive
# 2                 2      M        1987         Single          Alive
# 3                 3      F        1984        Married          Alive
# 4                 4      M        1993         Single          Alive
#
#        RACE            ETHNIC_GROUP EMPLOYMENT_STATUS DATA_SOURCE
# 0     White  Not Hispanic or Latino         Full Time    registry
# 1     White  Not Hispanic or Latino         Full Time    registry
# 2     White  Not Hispanic or Latino      Not Employed    registry
# 3     White  Not Hispanic or Latino      Not Employed    registry
# 4  Filipino  Not Hispanic or Latino      Not Employed    registry

# %% [markdown]
# #### Merge R3/registry

# %% [markdown]
# For now I'm ignoring the big demographic file because it has no STUDY_ID and it's hard to relate to everything else.

# %%
df_patients_merged = df_patients_r3.append(df_patients_registry)
print(df_patients_merged.shape)
df_patients_merged.head()
# Out:
# (6235, 10)
#     R3_STUDY_ID  BIRTH_YEAR  GENDER DATA_SOURCE MARITAL STATUS RACE  \
# 0  6.999995e+09        1958    MALE          r3
# 1  6.999993e+09        1928  FEMALE          r3
# 2  6.999997e+09        1958  FEMALE          r3
# 3  6.999948e+09        1954  FEMALE          r3
# 4  6.999947e+09        1988    MALE          r3
#
#   ETHNIC_GROUP EMPLOYMENT_STATUS PATIENT_STATUS  REGISTRY_AUTO_ID
# 0                                      Deceased               NaN
# 1                                      Deceased               NaN
# 2                                      Deceased               NaN
# 3                                      Deceased               NaN
# 4                                      Deceased               NaN

# %% [markdown]
# Note that a patient will have exactly one of `REGISTRY_AUTO_ID` or `R3_STUDY_ID`.

# %% [markdown]
# #### Standardize categoricals

# %%
df_patients_merged['GENDER'].unique()
# Out:
# array(['MALE', 'FEMALE', 'M', 'F'], dtype=object)

# %%
df_patients_merged['MARITAL STATUS'].unique()
# Out:
# array(['', 'Married', 'Single', 'Divorced', 'Widowed', 'Unknown',
#        'Legally Separated', nan, 'Committed relationship',
#        'Significant other'], dtype=object)

# %%
df_patients_merged['MARITAL STATUS'].replace([np.nan, 'Unknown'], '', inplace=True)
df_patients_merged['MARITAL STATUS'].unique()
# Out:
# array(['', 'Married', 'Single', 'Divorced', 'Widowed',
#        'Legally Separated', 'Committed relationship', 'Significant other'],
#       dtype=object)

# %%
df_patients_merged['RACE'].unique()
# Out:
# array(['', 'White', 'Filipino', nan, 'Declined', 'Black', 'Vietnamese',
#        'Not Specified', 'Indian (Asian)', 'Chinese', 'Other Asian',
#        'Alaska Native', 'American Indian', 'Japanese', 'Korean',
#        'Other Pacific Islander'], dtype=object)

# %%
df_patients_merged['RACE'].replace([np.nan, 'Declined', 'Not Specified'], '', inplace=True)
df_patients_merged['RACE'].unique()
# Out:
# array(['', 'White', 'Filipino', 'Black', 'Vietnamese', 'Indian (Asian)',
#        'Chinese', 'Other Asian', 'Alaska Native', 'American Indian',
#        'Japanese', 'Korean', 'Other Pacific Islander'], dtype=object)

# %%
df_patients_merged['EMPLOYMENT_STATUS'].unique()
# Out:
# array(['', 'Full Time', 'Not Employed', 'Student - Full Time', nan,
#        'Part Time', 'Retired', 'Self Employed', 'Unknown',
#        'Student - Part Time'], dtype=object)

# %%
df_patients_merged['EMPLOYMENT_STATUS'].replace([np.nan, 'Unknown'], '', inplace=True)
df_patients_merged['EMPLOYMENT_STATUS'].unique()
# Out:
# array(['', 'Full Time', 'Not Employed', 'Student - Full Time',
#        'Part Time', 'Retired', 'Self Employed', 'Student - Part Time'],
#       dtype=object)

# %%
df_patients_merged['ETHNIC_GROUP'].unique()
# Out:
# array(['', 'Not Hispanic or Latino', nan, 'Declined', 'Not Specified',
#        'Hispanic or Latino'], dtype=object)

# %%
df_patients_merged['ETHNIC_GROUP'].replace([np.nan, 'Declined', 'Not Specified'], '', inplace=True)
df_patients_merged['ETHNIC_GROUP'].unique()
# Out:
# array(['', 'Not Hispanic or Latino', 'Hispanic or Latino'], dtype=object)

# %%
df_patients_merged['IS_ALIVE'] = df_patients_merged['PATIENT_STATUS'].apply(lambda x: 'TRUE' if x == 'ALIVE' else 'FALSE')
df_patients_merged.drop(columns='PATIENT_STATUS', inplace=True)

# %% [markdown]
# #### Create our own unique ID

# %%
df_patients_merged['PROJECT_PATIENT_ID'] = df_patients_merged.apply(lambda x: str(uuid.uuid4()), axis=1)
df_patients_merged.head()
# Out:
#     R3_STUDY_ID  BIRTH_YEAR  GENDER DATA_SOURCE MARITAL STATUS RACE  \
# 0  6.999995e+09        1958    MALE          r3
# 1  6.999993e+09        1928  FEMALE          r3
# 2  6.999997e+09        1958  FEMALE          r3
# 3  6.999948e+09        1954  FEMALE          r3
# 4  6.999947e+09        1988    MALE          r3
#
#   ETHNIC_GROUP EMPLOYMENT_STATUS  REGISTRY_AUTO_ID IS_ALIVE  \
# 0                                              NaN    FALSE
# 1                                              NaN    FALSE
# 2                                              NaN    FALSE
# 3                                              NaN    FALSE
# 4                                              NaN    FALSE
#
#                      PROJECT_PATIENT_ID
# 0  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1  7da2e9db-ae3b-41bc-a467-fa2d9afe25ea
# 2  524c0db3-6ef0-47c6-9b99-098d0bf998cd
# 3  ed3a3f1a-0c26-402b-b922-159589036b46
# 4  4d3ea8f4-15b6-477f-805e-7932c6aabc74

# %% [markdown]
# #### Write out

# %%
# one version that relates the PAT_IDs and STUDY_IDs we do have to the original record
df_patients_merged.to_csv(f'{data_out_path}patients_master_deid.csv')

# one in the format needed by the preprocessing script
df_patients_merged.drop(columns=['R3_STUDY_ID', 'REGISTRY_AUTO_ID']).to_csv(f'{data_out_path}patients_merged.csv')

# %% [markdown]
# ### Encounters

# %% [markdown]
# We're only interested in encounters with the following departments:

# %%
encounter_dept_list = ['COLON RECTAL DDC HBC', 'GAS HBC OAKLAND DDC PH', 'GASTRO DDC', 'GASTRO IBD MED HOME', 'GI SURG DDC HBC']

# %% [markdown]
# #### Load R3

# %%
df_enc_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_ENCOUNTERS_2020_05_12.csv')
df_enc_r3.head()
# Out:
#      STUDY_ID   VISIT_ID           START_DATE END_DATE      ENC_TYPE  \
# 0  6999994666  452902438  09/21/2011 00:00:00      NaN  OFFICE VISIT
# 1  6999994666  450398659  10/10/2011 00:00:00      NaN  OFFICE VISIT
# 2  6999994666  452908020  09/07/2011 00:00:00      NaN     TELEPHONE
# 3  6999994666  452509743  09/12/2011 00:00:00      NaN   APPOINTMENT
# 4  6999994666  451199413  09/21/2011 00:00:00      NaN       HISTORY
#
#             LOCATION APPT_STATUS ADMIT_SOURCE HOSPITAL_SERVICE PATIENT_TYPE  \
# 0     PIMA GREENTREE   COMPLETED          NaN              NaN          NaN
# 1  RAVI GI GREENTREE   COMPLETED          NaN              NaN          NaN
# 2     PIMA GREENTREE         NaN          NaN              NaN          NaN
# 3     PIMA GREENTREE    CANCELED          NaN              NaN          NaN
# 4     PIMA GREENTREE         NaN          NaN              NaN          NaN
#
#   PATIENT_CLASS CHIEF_COMPLAINT CHIEF_COMPLAINT_ONSET_DATE
# 0           NaN             NaN                        NaN
# 1           NaN             NaN                        NaN
# 2           NaN             NaN                        NaN
# 3           NaN             NaN                        NaN
# 4           NaN             NaN                        NaN

# %% [markdown]
# Filter for the departments of interest.

# %%
df_enc_r3 = df_enc_r3[df_enc_r3['LOCATION'].isin(encounter_dept_list)]

# %% [markdown]
# **TODO:** New filter? 'CANCELED' seems like something we'd want to avoid in APPT_STATUS.

# %%
df_enc_r3['APPT_STATUS'].unique()
# Out:
# array([nan, 'COMPLETED', 'CANCELED', 'NO SHOW', 'UNRESOLVED'],
#       dtype=object)

# %%
df_enc_r3.drop(columns=[
    'END_DATE', 
    'ADMIT_SOURCE', 
    'HOSPITAL_SERVICE', 
    'PATIENT_TYPE', 
    'PATIENT_CLASS', 
    'CHIEF_COMPLAINT', 
    'CHIEF_COMPLAINT_ONSET_DATE',
    'APPT_STATUS',
    'VISIT_ID'
], inplace=True)
df_enc_r3.rename(columns = { 
    'START_DATE': 'ENCOUNTER_DATE',
    'ENC_TYPE': 'ENCOUNTER_TYPE',
    'LOCATION': 'DEPT_NAME'
}, inplace=True)
df_enc_r3['ICD9_CODE'] = ''
df_enc_r3['ICD10_CODE'] = ''
df_enc_r3['PRIMARY_DX'] = ''

df_enc_r3.head()
# Out:
#        STUDY_ID       ENCOUNTER_DATE ENCOUNTER_TYPE               DEPT_NAME  \
# 504  6999968167  08/01/2011 00:00:00      TELEPHONE         GI SURG DDC HBC
# 507  6999968167  08/05/2011 00:00:00      TELEPHONE         GI SURG DDC HBC
# 625  6999968167  04/20/2011 00:00:00      TELEPHONE  GAS HBC OAKLAND DDC PH
# 627  6999968167  04/21/2011 00:00:00           SCAN  GAS HBC OAKLAND DDC PH
# 628  6999968167  04/21/2011 00:00:00           SCAN         GI SURG DDC HBC
#
#     ICD9_CODE ICD10_CODE PRIMARY_DX
# 504
# 507
# 625
# 627
# 628

# %%
df_enc_r3[~df_enc_r3['STUDY_ID'].isin(df_patients_merged['R3_STUDY_ID'])]
# Out:
# Empty DataFrame
# Columns: [STUDY_ID, ENCOUNTER_DATE, ENCOUNTER_TYPE, DEPT_NAME, ICD9_CODE, ICD10_CODE, PRIMARY_DX]
# Index: []

# %%
df_enc_r3 = merge_project_patient_id(df_enc_r3, df_patients_merged, data_source = 'r3')
df_enc_r3.head()
# Out:
#         ENCOUNTER_DATE ENCOUNTER_TYPE               DEPT_NAME ICD9_CODE  \
# 0  08/01/2011 00:00:00      TELEPHONE         GI SURG DDC HBC
# 1  08/05/2011 00:00:00      TELEPHONE         GI SURG DDC HBC
# 2  04/20/2011 00:00:00      TELEPHONE  GAS HBC OAKLAND DDC PH
# 3  04/21/2011 00:00:00           SCAN  GAS HBC OAKLAND DDC PH
# 4  04/21/2011 00:00:00           SCAN         GI SURG DDC HBC
#
#   ICD10_CODE PRIMARY_DX                    PROJECT_PATIENT_ID
# 0                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 1                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 2                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 3                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 4                        c1c79322-d705-43c5-b5d2-d17689bbb5a9

# %% [markdown]
# #### Load registry

# %%
df_enc_registry = pd.read_excel(f'{data_in_registry_path}deid_IBD_Registry_BA1951_Office_Phone_Email_Encs_2020-01-05-09-43-50.xlsx')

# %%
# filter departments
df_enc_registry = df_enc_registry[df_enc_registry['DEPT_NAME'].isin(encounter_dept_list)]
print(df_enc_registry.shape)
df_enc_registry.head()
# Out:
# (137227, 12)
#    Unnamed: 0  AUTO_ID  ENC_TYPE_C ENC_TYPE_NAME         CONTACT_DATE  \
# 0           0        0         101  Office Visit  2010-10-14 00:00:00
# 1           1        0         101  Office Visit  2011-04-07 00:00:00
# 2           2        0         101  Office Visit  2011-07-07 00:00:00
# 3           3        0         101  Office Visit  2012-01-12 00:00:00
# 4           4        0         101  Office Visit  2012-07-12 00:00:00
#
#      DEPT_ID               DEPT_NAME  VISIT_PROV_ID   VISIT_PROV_NAME  \
# 0  1045102.0  GAS HBC OAKLAND DDC PH          58718  SCHWARTZ, MARC B
# 1  1045102.0  GAS HBC OAKLAND DDC PH          58718  SCHWARTZ, MARC B
# 2  1045102.0  GAS HBC OAKLAND DDC PH          58718  SCHWARTZ, MARC B
# 3  1045102.0  GAS HBC OAKLAND DDC PH          58718  SCHWARTZ, MARC B
# 4  1045102.0  GAS HBC OAKLAND DDC PH          58718  SCHWARTZ, MARC B
#
#   ICD9_CODE ICD10_CODE                       PRIMARY_DX
# 0     556.9     K51.90  Ulcerative colitis, unspecified
# 1     556.9     K51.90  Ulcerative colitis, unspecified
# 2     556.9     K51.90  Ulcerative colitis, unspecified
# 3     556.9     K51.90  Ulcerative colitis, unspecified
# 4     556.9     K51.90  Ulcerative colitis, unspecified

# %%
df_enc_registry = df_enc_registry[['AUTO_ID', 'ENC_TYPE_NAME', 'CONTACT_DATE', 'DEPT_NAME', 'ICD9_CODE', 'ICD10_CODE', 'PRIMARY_DX']]
df_enc_registry.rename(columns={
    'ENC_TYPE_NAME': 'ENCOUNTER_TYPE',
    'CONTACT_DATE': 'ENCOUNTER_DATE'
}, inplace=True)
df_enc_registry.head()
# Out:
#    AUTO_ID ENCOUNTER_TYPE       ENCOUNTER_DATE               DEPT_NAME  \
# 0        0   Office Visit  2010-10-14 00:00:00  GAS HBC OAKLAND DDC PH
# 1        0   Office Visit  2011-04-07 00:00:00  GAS HBC OAKLAND DDC PH
# 2        0   Office Visit  2011-07-07 00:00:00  GAS HBC OAKLAND DDC PH
# 3        0   Office Visit  2012-01-12 00:00:00  GAS HBC OAKLAND DDC PH
# 4        0   Office Visit  2012-07-12 00:00:00  GAS HBC OAKLAND DDC PH
#
#   ICD9_CODE ICD10_CODE                       PRIMARY_DX
# 0     556.9     K51.90  Ulcerative colitis, unspecified
# 1     556.9     K51.90  Ulcerative colitis, unspecified
# 2     556.9     K51.90  Ulcerative colitis, unspecified
# 3     556.9     K51.90  Ulcerative colitis, unspecified
# 4     556.9     K51.90  Ulcerative colitis, unspecified

# %%
df_enc_registry = merge_project_patient_id(df_enc_registry, df_patients_merged, data_source='registry')
print(df_enc_registry.shape)
df_enc_registry.head()
# Out:
# (137227, 7)
#   ENCOUNTER_TYPE       ENCOUNTER_DATE               DEPT_NAME ICD9_CODE  \
# 0   Office Visit  2010-10-14 00:00:00  GAS HBC OAKLAND DDC PH     556.9
# 1   Office Visit  2011-04-07 00:00:00  GAS HBC OAKLAND DDC PH     556.9
# 2   Office Visit  2011-07-07 00:00:00  GAS HBC OAKLAND DDC PH     556.9
# 3   Office Visit  2012-01-12 00:00:00  GAS HBC OAKLAND DDC PH     556.9
# 4   Office Visit  2012-07-12 00:00:00  GAS HBC OAKLAND DDC PH     556.9
#
#   ICD10_CODE                       PRIMARY_DX  \
# 0     K51.90  Ulcerative colitis, unspecified
# 1     K51.90  Ulcerative colitis, unspecified
# 2     K51.90  Ulcerative colitis, unspecified
# 3     K51.90  Ulcerative colitis, unspecified
# 4     K51.90  Ulcerative colitis, unspecified
#
#                      PROJECT_PATIENT_ID
# 0  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 1  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 2  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 3  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 4  b8d4e6bd-e1b7-4a36-8df1-911926190d53

# %% [markdown]
# #### Merge data sources

# %%
df_enc_merged = df_enc_r3.append(df_enc_registry)
print(df_enc_merged.shape)
df_enc_merged.head()
# Out:
# (149741, 7)
#         ENCOUNTER_DATE ENCOUNTER_TYPE               DEPT_NAME ICD9_CODE  \
# 0  08/01/2011 00:00:00      TELEPHONE         GI SURG DDC HBC
# 1  08/05/2011 00:00:00      TELEPHONE         GI SURG DDC HBC
# 2  04/20/2011 00:00:00      TELEPHONE  GAS HBC OAKLAND DDC PH
# 3  04/21/2011 00:00:00           SCAN  GAS HBC OAKLAND DDC PH
# 4  04/21/2011 00:00:00           SCAN         GI SURG DDC HBC
#
#   ICD10_CODE PRIMARY_DX                    PROJECT_PATIENT_ID
# 0                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 1                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 2                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 3                        c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 4                        c1c79322-d705-43c5-b5d2-d17689bbb5a9

# %% [markdown]
# #### Standardized categoricals

# %%
df_enc_merged['ENCOUNTER_TYPE'].unique()
# Out:
# array(['TELEPHONE', 'SCAN', 'OFFICE VISIT', 'HISTORY', 'REFILL',
#        'INFORMATIONAL', 'PROCEDURE NOTE', 'APPOINTMENT',
#        'TREATMENT PROTOCOL', 'LETTER', 'ERRONEOUS ENCOUNTER',
#        'RELEASE OF INFORMATION', 'OP REPORT', 'PATIENT EMAIL',
#        'ORDERS ONLY', 'ABSTRACT', 'LETTER (OUT)', 'LAB RESULTS', 'BPA',
#        'HOSPITAL RESERVATION', 'IMAGING', 'LAB VISIT',
#        'NEW PATIENT VISIT', 'IP CONSULT', 'TRANSCRIPTION', 'EKG',
#        'PROCEDURE VISIT', 'TESTING VISIT', 'TRANSFER SUMMARY',
#        'INPATIENT H&P', 'NUTRITION', 'SURGERY SCHEDULING', 'GI',
#        'Office Visit', 'New Patient Visit', 'Patient Message',
#        'Telephone', 'Procedure Visit', 'Consult'], dtype=object)

# %%
df_enc_merged['ENCOUNTER_TYPE'] = df_enc_merged['ENCOUNTER_TYPE'].str.upper()
df_enc_merged['ENCOUNTER_TYPE'].unique()
# Out:
# array(['TELEPHONE', 'SCAN', 'OFFICE VISIT', 'HISTORY', 'REFILL',
#        'INFORMATIONAL', 'PROCEDURE NOTE', 'APPOINTMENT',
#        'TREATMENT PROTOCOL', 'LETTER', 'ERRONEOUS ENCOUNTER',
#        'RELEASE OF INFORMATION', 'OP REPORT', 'PATIENT EMAIL',
#        'ORDERS ONLY', 'ABSTRACT', 'LETTER (OUT)', 'LAB RESULTS', 'BPA',
#        'HOSPITAL RESERVATION', 'IMAGING', 'LAB VISIT',
#        'NEW PATIENT VISIT', 'IP CONSULT', 'TRANSCRIPTION', 'EKG',
#        'PROCEDURE VISIT', 'TESTING VISIT', 'TRANSFER SUMMARY',
#        'INPATIENT H&P', 'NUTRITION', 'SURGERY SCHEDULING', 'GI',
#        'PATIENT MESSAGE', 'CONSULT'], dtype=object)

# %% [markdown]
# #### Write out

# %%
df_enc_merged.to_csv(f'{data_out_path}encounters_merged.csv')

# %% [markdown]
# ### Labs

# %% [markdown]
# #### R3

# %%
df_labs_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_LAB_RESULTS_2020_05_12.csv')
df_labs_r3.head()
# Out:
#      STUDY_ID   VISIT_ID  ORDER_PROC_ID RESULT_DATE        COMPONENT_NAME  \
# 0  6999997423  351489117      203602100  03/27/2015  SPECIMEN DESCRIPTION
# 1  6999997423  351489117      203602100  03/27/2015      SPECIAL REQUESTS
# 2  6999997423  351489117      203602100  03/27/2015               CULTURE
# 3  6999997423  351489117      203602100  03/27/2015                REPORT
# 4  6999997423  351489117      114670251  03/23/2015                LIPASE
#
#                  ORD_VALUE  ORD_NUM_VALUE REFERENCE_UNIT REFERENCE_LOW  \
# 0                    Stool            NaN            NaN           NaN
# 1                     None            NaN            NaN           NaN
# 2                      NaN            NaN            NaN           NaN
# 3  Final Result 03/27/2015            NaN            NaN           NaN
# 4                      164          164.0            U/L            50
#
#   REFERENCE_HIGH RESULT_FLAG LAB_RESULT_STATUS SPECIMEN_COLLECTED_DATE  \
# 0            NaN         NaN             FINAL              03/25/2015
# 1            NaN         NaN             FINAL              03/25/2015
# 2            NaN         NaN             FINAL              03/25/2015
# 3            NaN         NaN             FINAL              03/25/2015
# 4            393         NaN             FINAL              03/23/2015
#
#   SPECIMEN_RECEIVED_DATE SPECIMEN_TYPE  SPECIMEN_SOURCE
# 0             03/25/2015         STOOL              NaN
# 1             03/25/2015         STOOL              NaN
# 2             03/25/2015         STOOL              NaN
# 3             03/25/2015         STOOL              NaN
# 4             03/23/2015           NaN              NaN

# %%
df_labs_r3 = df_labs_r3[[
    'STUDY_ID', 
    'RESULT_DATE', 
    'ORDER_PROC_ID', 
    'COMPONENT_NAME', 
    'ORD_VALUE', 
    'ORD_NUM_VALUE', 
    'REFERENCE_UNIT',
    'REFERENCE_LOW', 
    'REFERENCE_HIGH', 
    'RESULT_FLAG'
]]
df_labs_r3['GROUP'] = ''
df_labs_r3.head()
# Out:
#      STUDY_ID RESULT_DATE  ORDER_PROC_ID        COMPONENT_NAME  \
# 0  6999997423  03/27/2015      203602100  SPECIMEN DESCRIPTION
# 1  6999997423  03/27/2015      203602100      SPECIAL REQUESTS
# 2  6999997423  03/27/2015      203602100               CULTURE
# 3  6999997423  03/27/2015      203602100                REPORT
# 4  6999997423  03/23/2015      114670251                LIPASE
#
#                  ORD_VALUE  ORD_NUM_VALUE REFERENCE_UNIT REFERENCE_LOW  \
# 0                    Stool            NaN            NaN           NaN
# 1                     None            NaN            NaN           NaN
# 2                      NaN            NaN            NaN           NaN
# 3  Final Result 03/27/2015            NaN            NaN           NaN
# 4                      164          164.0            U/L            50
#
#   REFERENCE_HIGH RESULT_FLAG GROUP
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            393         NaN

# %%
df_labs_r3 = merge_project_patient_id(df_labs_r3, df_patients_merged, 'r3')
df_labs_r3.head()
# Out:
#   RESULT_DATE  ORDER_PROC_ID        COMPONENT_NAME                ORD_VALUE  \
# 0  03/27/2015      203602100  SPECIMEN DESCRIPTION                    Stool
# 1  03/27/2015      203602100      SPECIAL REQUESTS                     None
# 2  03/27/2015      203602100               CULTURE                      NaN
# 3  03/27/2015      203602100                REPORT  Final Result 03/27/2015
# 4  03/23/2015      114670251                LIPASE                      164
#
#    ORD_NUM_VALUE REFERENCE_UNIT REFERENCE_LOW REFERENCE_HIGH RESULT_FLAG  \
# 0            NaN            NaN           NaN            NaN         NaN
# 1            NaN            NaN           NaN            NaN         NaN
# 2            NaN            NaN           NaN            NaN         NaN
# 3            NaN            NaN           NaN            NaN         NaN
# 4          164.0            U/L            50            393         NaN
#
#   GROUP                    PROJECT_PATIENT_ID
# 0        524c0db3-6ef0-47c6-9b99-098d0bf998cd
# 1        524c0db3-6ef0-47c6-9b99-098d0bf998cd
# 2        524c0db3-6ef0-47c6-9b99-098d0bf998cd
# 3        524c0db3-6ef0-47c6-9b99-098d0bf998cd
# 4        524c0db3-6ef0-47c6-9b99-098d0bf998cd

# %% [markdown]
# #### Registry

# %%
df_labs_registry = pd.read_excel(f'{data_in_registry_path}labs_filtered.xlsx')
df_labs_registry.head()
# Out:
#    Unnamed: 0  AUTO_ID           ORDER_DATE PROC_CODE  \
# 0           2        0  2010-08-12 00:00:00   8502502
# 1           4        0  2010-08-12 00:00:00   8502502
# 2           7        0  2010-08-12 00:00:00   8007602
# 3          20        0  2010-08-12 00:00:00   8614001
# 4          23        0  2010-08-12 00:00:00   8502502
#
#                  PROC_NAME ORDER_STATUS CPT_CODE  LAB_COMP_ID  \
# 0  CBC & DIFF INC PLATELET    Completed    85025           74
# 1  CBC & DIFF INC PLATELET    Completed    85025           72
# 2   HEPATIC FUNCTION PANEL    Completed     HFPA           20
# 3         CRP QUANTITATION    Completed    86140          530
# 4  CBC & DIFF INC PLATELET    Completed    85025           73
#
#       LAB_COMP_NAME          RESULT_DATE ORD_VALUE  ORD_NUM_VALUE REF_LOW  \
# 0   ABS EOSINOPHILS  2010-08-12 00:00:00      0.00          0.000    0.00
# 1     ABS MONOCYTES  2010-08-12 00:00:00      0.50          0.500    0.30
# 2           ALBUMIN  2010-08-12 00:00:00       2.9          2.900     3.4
# 3  CRP QUANTITATION  2010-08-12 00:00:00    10.085         10.085  <0.748
# 4       EOSINOPHILS  2010-08-12 00:00:00         0          0.000       0
#
#   REF_HIGH REF_NORMAL_VALS   REF_UNIT RESULT_FLAG      GROUP
# 0      0.4             NaN  X10E+09/L         NaN        eos
# 1      0.9             NaN  X10E+09/L         NaN  monocytes
# 2      5.0             NaN       g/dL         Low    albumin
# 3      NaN             NaN      mg/dL        High        crp
# 4        6             NaN          %         NaN        eos

# %%
df_labs_registry = df_labs_registry[[
    'AUTO_ID', 
    'RESULT_DATE', 
    'LAB_COMP_ID', 
    'LAB_COMP_NAME', 
    'ORD_VALUE',
    'ORD_NUM_VALUE', 
    'REF_UNIT', 
    'REF_LOW', 
    'REF_HIGH', 
    'RESULT_FLAG', 
    'GROUP'
]]

df_labs_registry.rename(columns={
    'LAB_COMP_ID': 'ORDER_PROC_ID',
    'LAB_COMP_NAME': 'COMPONENT_NAME',
    'REF_UNIT': 'REFERENCE_UNIT',
    'REF_LOW': 'REFERENCE_LOW',
    'REF_HIGH': 'REFERENCE_HIGH',
}, inplace=True)

df_labs_registry = merge_project_patient_id(df_labs_registry, df_patients_merged, 'registry')
df_labs_registry.head()
# Out:
#            RESULT_DATE  ORDER_PROC_ID    COMPONENT_NAME ORD_VALUE  \
# 0  2010-08-12 00:00:00             74   ABS EOSINOPHILS      0.00
# 1  2010-08-12 00:00:00             72     ABS MONOCYTES      0.50
# 2  2010-08-12 00:00:00             20           ALBUMIN       2.9
# 3  2010-08-12 00:00:00            530  CRP QUANTITATION    10.085
# 4  2010-08-12 00:00:00             73       EOSINOPHILS         0
#
#    ORD_NUM_VALUE REFERENCE_UNIT REFERENCE_LOW REFERENCE_HIGH RESULT_FLAG  \
# 0          0.000      X10E+09/L          0.00            0.4         NaN
# 1          0.500      X10E+09/L          0.30            0.9         NaN
# 2          2.900           g/dL           3.4            5.0         Low
# 3         10.085          mg/dL        <0.748            NaN        High
# 4          0.000              %             0              6         NaN
#
#        GROUP                    PROJECT_PATIENT_ID
# 0        eos  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 1  monocytes  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 2    albumin  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 3        crp  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 4        eos  b8d4e6bd-e1b7-4a36-8df1-911926190d53

# %% [markdown]
# #### Merge data sources

# %%
df_labs_merged = df_labs_r3.append(df_labs_registry)
df_labs_merged.shape
# Out:
# (1486967, 11)

# %% [markdown]
# #### Cleanup

# %% [markdown]
# Set the `GROUP` column for all entries.

# %%
df_labs_merged['GROUP'] = df_labs_merged['GROUP'].replace(np.nan, '')
df_labs_merged['GROUP'].unique()
# Out:
# array(['', 'eos', 'monocytes', 'albumin', 'crp', 'hemoglobin', 'esr',
#        'vitamin_d'], dtype=object)

# %%
df_labs_merged['GROUP'] = df_labs_merged.apply(lambda x: x['GROUP'] if x['GROUP'] != '' else get_lab_group(x['COMPONENT_NAME']), axis='columns')
print('total labs', df_labs_merged.shape[0])
print('labs without a group', df_labs_merged[df_labs_merged['GROUP'] == ''].shape[0])
# Out:
# total labs 1486967
# labs without a group 945527

# %% [markdown]
# **TODO:** Confirm these result flag cleanup decisions.

# %%
# standardize casing
df_labs_merged['RESULT_FLAG'] = df_labs_merged['RESULT_FLAG'].str.upper()
# set default blank
df_labs_merged['RESULT_FLAG'] = df_labs_merged['RESULT_FLAG'].replace(['(NONE)', np.nan], '')
# ignore "panic" for now - everything is either high, low, abnormal, or nothing
df_labs_merged['RESULT_FLAG'] = df_labs_merged['RESULT_FLAG'].replace('PANIC', 'ABNORMAL')
df_labs_merged['RESULT_FLAG'] = df_labs_merged['RESULT_FLAG'].str.replace(' PANIC', '')
df_labs_merged['RESULT_FLAG'].unique()
# Out:
# array(['', 'HIGH', 'LOW', 'ABNORMAL'], dtype=object)

# %% [markdown]
# #### Write out

# %%
df_labs_merged.to_csv(f'{data_out_path}labs_merged.csv')

# %% [markdown]
# ### Meds

# %% [markdown]
# #### R3

# %%
df_meds_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_MED_ORDERS_2020_05_12.csv')
df_meds_r3 = df_meds_r3[['STUDY_ID', 'MED_ORDER_ID', 'MEDICATION_NAME', 'SIMPLE_GENERIC', 'ORDER_DATE', 'START_DATE', 'END_DATE', 'PHARM_CLASS']]
df_meds_r3.head()
# Out:
# D:\miniconda3\envs\ibd-precision-medicine\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      STUDY_ID  MED_ORDER_ID  \
# 0  6999994666     367023442
# 1  6999994666     367023441
# 2  6999994666     367023443
# 3  6999994666     367023438
# 4  6999994666     146936464
#
#                                      MEDICATION_NAME  \
# 0                            LISINOPRIL 10 MG TABLET
# 1                             LISINOPRIL 5 MG TABLET
# 2                       LEVOTHYROXINE 100 MCG TABLET
# 3  VARICELLA-ZOSTER GLYCOE VACC-AS01B ADJ(PF) 50 ...
# 4                           SIMVASTATIN 20 MG TABLET
#
#                  SIMPLE_GENERIC  ORDER_DATE  START_DATE    END_DATE  \
# 0                    LISINOPRIL  08/13/2018  08/13/2018         NaN
# 1                    LISINOPRIL  08/13/2018  08/13/2018         NaN
# 2          LEVOTHYROXINE SODIUM  08/13/2018  08/13/2018         NaN
# 3  VARICELLA-ZOSTER GE/AS01B/PF  08/13/2018  08/13/2018  08/13/2018
# 4                   SIMVASTATIN  01/16/2014  01/16/2014  04/25/2014
#
#                                          PHARM_CLASS
# 0                  ANTIHYPERTENSIVES, ACE INHIBITORS
# 1                  ANTIHYPERTENSIVES, ACE INHIBITORS
# 2                                   THYROID HORMONES
# 3                         VIRAL/TUMORIGENIC VACCINES
# 4  ANTIHYPERLIPIDEMIC - HMG COA REDUCTASE INHIBITORS

# %%
df_meds_r3.rename(columns={ 
    'MED_ORDER_ID': 'ORDER_ID',
    'MEDICATION_NAME': 'MED_NAME',
    'SIMPLE_GENERIC': 'SIMPLE_GENERIC_NAME',
    'ORDER_DATE': 'ORDERING_DATE'
}, inplace=True)
df_meds_r3['GROUP'] = ''
df_meds_r3 = merge_project_patient_id(df_meds_r3, df_patients_merged, 'r3')
df_meds_r3.head()
# Out:
#     ORDER_ID                                           MED_NAME  \
# 0  367023442                            LISINOPRIL 10 MG TABLET
# 1  367023441                             LISINOPRIL 5 MG TABLET
# 2  367023443                       LEVOTHYROXINE 100 MCG TABLET
# 3  367023438  VARICELLA-ZOSTER GLYCOE VACC-AS01B ADJ(PF) 50 ...
# 4  146936464                           SIMVASTATIN 20 MG TABLET
#
#             SIMPLE_GENERIC_NAME ORDERING_DATE  START_DATE    END_DATE  \
# 0                    LISINOPRIL    08/13/2018  08/13/2018         NaN
# 1                    LISINOPRIL    08/13/2018  08/13/2018         NaN
# 2          LEVOTHYROXINE SODIUM    08/13/2018  08/13/2018         NaN
# 3  VARICELLA-ZOSTER GE/AS01B/PF    08/13/2018  08/13/2018  08/13/2018
# 4                   SIMVASTATIN    01/16/2014  01/16/2014  04/25/2014
#
#                                          PHARM_CLASS GROUP  \
# 0                  ANTIHYPERTENSIVES, ACE INHIBITORS
# 1                  ANTIHYPERTENSIVES, ACE INHIBITORS
# 2                                   THYROID HORMONES
# 3                         VIRAL/TUMORIGENIC VACCINES
# 4  ANTIHYPERLIPIDEMIC - HMG COA REDUCTASE INHIBITORS
#
#                      PROJECT_PATIENT_ID
# 0  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  64a0ac31-091d-45c5-86e3-86516ee4299a

# %% [markdown]
# #### Registry

# %%
df_meds_registry = pd.read_excel(f'{data_in_registry_path}filtered_meds.xlsx')
df_meds_registry = df_meds_registry[['AUTO_ID', 'ORDER_ID', 'MED_NAME', 'SIMPLE_GENERIC_NAME', 'ORDERING_DATE', 'START_DATE', 'END_DATE', 'PHARM_CLASS', 'GROUP']]
df_meds_registry = merge_project_patient_id(df_meds_registry, df_patients_merged, 'registry')
df_meds_registry.head()
# Out:
#    ORDER_ID                                  MED_NAME SIMPLE_GENERIC_NAME  \
# 0  41818775                 AZATHIOPRINE 50 MG TABLET        AZATHIOPRINE
# 1  41818777  MESALAMINE 400 MG TABLET,DELAYED RELEASE          MESALAMINE
# 2  41818779                           MESALAMINE RECT          MESALAMINE
# 3  54197256                   PREDNISONE 20 MG TABLET          PREDNISONE
# 4  54424224                 AZATHIOPRINE 50 MG TABLET        AZATHIOPRINE
#
#          ORDERING_DATE           START_DATE             END_DATE  \
# 0  2010-08-12 00:00:00                  NaN  2010-08-20 00:00:00
# 1  2010-08-12 00:00:00                  NaN  2011-04-07 00:00:00
# 2  2010-08-12 00:00:00                  NaN  2011-04-07 00:00:00
# 3  2010-08-12 00:00:00  2010-08-12 00:00:00  2011-04-07 00:00:00
# 4  2010-08-20 00:00:00  2010-08-20 00:00:00  2011-01-07 00:00:00
#
#                                          PHARM_CLASS              GROUP  \
# 0                                 IMMUNOSUPPRESSIVES   Immunomodulators
# 1  DRUG TX-CHRONIC INFLAM. COLON DX,5-AMINOSALICYLAT              5 ASA
# 2  CHRONIC INFLAM. COLON DX, 5-A-SALICYLAT,RECTAL TX              5 ASA
# 3                                    GLUCOCORTICOIDS  Systemic steroids
# 4                                 IMMUNOSUPPRESSIVES   Immunomodulators
#
#                      PROJECT_PATIENT_ID
# 0  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 1  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 2  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 3  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 4  b8d4e6bd-e1b7-4a36-8df1-911926190d53

# %% [markdown]
# #### Merge data sources

# %%
df_meds_merged = df_meds_r3.append(df_meds_registry)
df_meds_merged.head()
# Out:
#     ORDER_ID                                           MED_NAME  \
# 0  367023442                            LISINOPRIL 10 MG TABLET
# 1  367023441                             LISINOPRIL 5 MG TABLET
# 2  367023443                       LEVOTHYROXINE 100 MCG TABLET
# 3  367023438  VARICELLA-ZOSTER GLYCOE VACC-AS01B ADJ(PF) 50 ...
# 4  146936464                           SIMVASTATIN 20 MG TABLET
#
#             SIMPLE_GENERIC_NAME ORDERING_DATE  START_DATE    END_DATE  \
# 0                    LISINOPRIL    08/13/2018  08/13/2018         NaN
# 1                    LISINOPRIL    08/13/2018  08/13/2018         NaN
# 2          LEVOTHYROXINE SODIUM    08/13/2018  08/13/2018         NaN
# 3  VARICELLA-ZOSTER GE/AS01B/PF    08/13/2018  08/13/2018  08/13/2018
# 4                   SIMVASTATIN    01/16/2014  01/16/2014  04/25/2014
#
#                                          PHARM_CLASS GROUP  \
# 0                  ANTIHYPERTENSIVES, ACE INHIBITORS
# 1                  ANTIHYPERTENSIVES, ACE INHIBITORS
# 2                                   THYROID HORMONES
# 3                         VIRAL/TUMORIGENIC VACCINES
# 4  ANTIHYPERLIPIDEMIC - HMG COA REDUCTASE INHIBITORS
#
#                      PROJECT_PATIENT_ID
# 0  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  64a0ac31-091d-45c5-86e3-86516ee4299a

# %% [markdown]
# #### Cleanup

# %%
# filter non-ibd meds
df_meds_merged = df_meds_merged[df_meds_merged.apply(lambda x: get_is_ibd_med(x['SIMPLE_GENERIC_NAME']), axis='columns')]
df_meds_merged.shape
# Out:
# (88402, 9)

# %%
# set group name
df_meds_merged['GROUP'] = df_meds_merged.apply(lambda x: x['GROUP'] if x['GROUP'] != '' else get_med_group(x['SIMPLE_GENERIC_NAME'], x['MED_NAME']), axis='columns')
df_meds_merged_nogroup = df_meds_merged[df_meds_merged['GROUP'] == '']

print('Total meds:', len(df_meds_merged))
print('Meds (no group):', len(df_meds_merged_nogroup))
df_meds_merged = df_meds_merged[df_meds_merged['GROUP'] != '']
# Out:
# Total meds: 88402
# Meds (no group): 13492

# %% [markdown]
# **TODO:** Do we need to deal with these generics/med names with no group? Many of these have generic names that are related to groups in the meds dict. Basically, confirm Dmitriy's logic for this.

# %%
df_meds_merged_nogroup['SIMPLE_GENERIC_NAME'].unique()
# Out:
# array(['HYDROCORTISONE', 'HYDROCORTISONE SOD SUCCINATE',
#        'CHOLECALCIFEROL (VITAMIN D3)', 'PREDNISONE', 'MERCAPTOPURINE',
#        'MESALAMINE', 'PREDNISOLONE', 'ADALIMUMAB',
#        'DEXAMETHASONE SOD PHOSPHATE', 'CALCIUM CARBONATE/VITAMIN D3',
#        'ERGOCALCIFEROL (VITAMIN D2)', 'AZATHIOPRINE',
#        'CERTOLIZUMAB PEGOL', 'DEXAMETHASONE', 'METHYLPREDNISOLONE',
#        'METHOTREXATE SODIUM/PF', 'METHOTREXATE SODIUM', 'METHOTREXATE/PF',
#        'SULFASALAZINE', 'METHYLPREDNISOLONE SOD SUCC',
#        'PREDNISOLONE SOD PHOSPHATE', 'METHOTREXATE', 'ETANERCEPT',
#        'GOLIMUMAB', 'USTEKINUMAB', 'LEFLUNOMIDE',
#        'METHYLPREDNISOLONE SOD SUCC/PF', 'METHYLPREDNISOLONE ACETATE',
#        'MESALAMINE W/CLEANSING WIPES', 'HYDROCORTISONE SOD PHOSPHATE'],
#       dtype=object)

# %% [markdown]
# #### Write out

# %%
df_meds_merged.to_csv(f'{data_out_path}meds_merged.csv')

# %% [markdown]
# ### Diagnoses

# %% [markdown]
# #### R3

# %% [markdown]
# ##### Problem list

# %%
df_problems_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_PROB_LIST_2020_05_12.csv')
df_problems_r3.head()
# Out:
#      STUDY_ID DX_CODE_TYPE  DX_CODE  \
# 0  6999994666         ICD9   535.50
# 1  6999994666         ICD9    578.1
# 2  6999994666         ICD9    555.2
# 3  6999994666        ICD10    H26.9
# 4  6999994666        ICD10  H04.129
#
#                                              DX_NAME REPORTED_DATE  \
# 0  Unspecified gastritis and gastroduodenitis wit...    11/15/2011
# 1                                     Blood in stool    10/10/2011
# 2  Regional enteritis of small intestine with lar...    04/04/2012
# 3                                           Cataract    06/20/2016
# 4                                            Dry eye    06/20/2016
#
#    ONSET_DATE RESOLVED_DATE  RESOLVED_REASON PROBLEM_STATUS
# 0  11/15/2011           NaN              NaN         ACTIVE
# 1  10/10/2011           NaN              NaN         ACTIVE
# 2  04/04/2012           NaN              NaN         ACTIVE
# 3  06/20/2016           NaN              NaN         ACTIVE
# 4  06/20/2016           NaN              NaN         ACTIVE

# %%
df_problems_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_PROB_LIST_2020_05_12.csv')
df_problems_r3 = df_problems_r3[['STUDY_ID', 'DX_CODE_TYPE', 'DX_CODE', 'DX_NAME','ONSET_DATE']]
df_problems_r3.rename(columns={ 'ONSET_DATE': 'DX_DATE' }, inplace=True)
df_problems_r3 = merge_project_patient_id(df_problems_r3, df_patients_merged, 'r3')
df_problems_r3.head()
# Out:
#   DX_CODE_TYPE  DX_CODE                                            DX_NAME  \
# 0         ICD9   535.50  Unspecified gastritis and gastroduodenitis wit...
# 1         ICD9    578.1                                     Blood in stool
# 2         ICD9    555.2  Regional enteritis of small intestine with lar...
# 3        ICD10    H26.9                                           Cataract
# 4        ICD10  H04.129                                            Dry eye
#
#       DX_DATE                    PROJECT_PATIENT_ID
# 0  11/15/2011  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1  10/10/2011  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2  04/04/2012  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  06/20/2016  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  06/20/2016  64a0ac31-091d-45c5-86e3-86516ee4299a

# %% [markdown]
# ##### Dx

# %%
df_dx_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_DIAGNOSES_2020_05_12.csv')
df_dx_r3.head()
# Out:
#      STUDY_ID   VISIT_ID DIAGNOSIS_TYPE DX_CODE  \
# 0  6999994666  463260127         ICD9CM  790.29
# 1  6999994666  476176269         ICD9CM   543.9
# 2  6999994666  476176269         ICD9CM   455.6
# 3  6999994666  463591352         ICD9CM   V81.1
# 4  6999994666  463591352        ICD10CM   V81.1
#
#                                       DIAGNOSIS_NAME PRIMARY_DX_IND  \
# 0                             Other abnormal glucose              Y
# 1         Other and unspecified diseases of appendix              N
# 2  Unspecified hemorrhoids without mention of com...              N
# 3                         Screening for hypertension              N
# 4  Occupant of railway train or railway vehicle i...              N
#
#   DX_FROM_DATE DX_TO_DATE
# 0   11/11/2014        NaN
# 1   11/05/2014        NaN
# 2   11/05/2014        NaN
# 3   11/07/2014        NaN
# 4   11/07/2014        NaN

# %%
df_dx_r3 = df_dx_r3[['STUDY_ID', 'DIAGNOSIS_TYPE', 'DX_CODE', 'DIAGNOSIS_NAME','DX_FROM_DATE']]
df_dx_r3.rename(columns={
    'DIAGNOSIS_TYPE': 'DX_CODE_TYPE',
    'DIAGNOSIS_NAME': 'DX_NAME',
    'DX_FROM_DATE': 'DX_DATE'
}, inplace=True)
df_dx_r3 = merge_project_patient_id(df_dx_r3, df_patients_merged, 'r3')
df_dx_r3.head()
# Out:
#   DX_CODE_TYPE DX_CODE                                            DX_NAME  \
# 0       ICD9CM  790.29                             Other abnormal glucose
# 1       ICD9CM   543.9         Other and unspecified diseases of appendix
# 2       ICD9CM   455.6  Unspecified hemorrhoids without mention of com...
# 3       ICD9CM   V81.1                         Screening for hypertension
# 4      ICD10CM   V81.1  Occupant of railway train or railway vehicle i...
#
#       DX_DATE                    PROJECT_PATIENT_ID
# 0  11/11/2014  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1  11/05/2014  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2  11/05/2014  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  11/07/2014  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  11/07/2014  64a0ac31-091d-45c5-86e3-86516ee4299a

# %% [markdown]
# #### Registry

# %% [markdown]
# **TODO:** registry has `PROBLEM_STATUS` field which, combined with `UPDATE_DATE`, might give us higher fidelity on some of these.

# %%
df_dx_registry = pd.read_excel(f'{data_in_registry_path}deid_IBD_Registry_BA1951_Problem_List_2020-01-05-09-30-19.xls')
df_dx_registry.head()
# Out:
#    Unnamed: 0  AUTO_ID        DATE_OF_ENTRY           NOTED_DATE  \
# 0           0        0  2018-11-14 00:00:00  2009-08-27 00:00:00
# 1           1        0  2018-11-14 00:00:00  2009-08-27 00:00:00
# 2           2        0  2014-04-03 00:00:00  2010-04-07 00:00:00
# 3           3        0  2014-04-03 00:00:00  2010-04-07 00:00:00
# 4           4        0  2014-04-03 00:00:00  2010-11-29 00:00:00
#
#   RESOLVED_DATE          UPDATE_DATE PROBLEM_DESCRIPTION ICD9_CODE  \
# 0           NaN  2018-11-14 14:06:00                 NaN    715.26
# 1           NaN  2018-11-14 14:06:00                 NaN    719.46
# 2           NaN  2015-07-28 12:14:00                 NaN     836.1
# 3           NaN  2015-07-28 12:14:00                 NaN    727.09
# 4           NaN  2015-07-28 12:14:00                 NaN    727.05
#
#          ICD10_CODE                                     DIAGNOSIS_NAME  \
# 0            M17.31        Post-traumatic osteoarthritis of right knee
# 1           M25.569                           Pain in joint, lower leg
# 2          S83.289A  Tear of lateral cartilage or meniscus of knee,...
# 3            M65.80                  Other synovitis and tenosynovitis
# 4  M65.849, M65.839              Other tenosynovitis of hand and wrist
#
#   CLASS_OF_PROBLEM  PROBLEM_TYPE PROBLEM_STATUS PRIORITY
# 0              NaN           NaN         ACTIVE      NaN
# 1              NaN           NaN        DELETED      NaN
# 2              NaN           NaN         ACTIVE      NaN
# 3              NaN           NaN         ACTIVE      NaN
# 4              NaN           NaN         ACTIVE      NaN

# %%
df_dx_registry = df_dx_registry[['AUTO_ID', 'ICD10_CODE', 'DIAGNOSIS_NAME', 'DATE_OF_ENTRY']]
df_dx_registry.rename(columns={
    'DIAGNOSIS_NAME': 'DX_NAME',
    'DATE_OF_ENTRY': 'DX_DATE',
    'ICD10_CODE': 'DX_CODE'
}, inplace=True)
df_dx_registry['DX_CODE_TYPE'] = 'ICD10'
df_dx_registry = merge_project_patient_id(df_dx_registry, df_patients_merged, 'registry')
df_dx_registry.head()
# Out:
#             DX_CODE                                            DX_NAME  \
# 0            M17.31        Post-traumatic osteoarthritis of right knee
# 1           M25.569                           Pain in joint, lower leg
# 2          S83.289A  Tear of lateral cartilage or meniscus of knee,...
# 3            M65.80                  Other synovitis and tenosynovitis
# 4  M65.849, M65.839              Other tenosynovitis of hand and wrist
#
#                DX_DATE DX_CODE_TYPE                    PROJECT_PATIENT_ID
# 0  2018-11-14 00:00:00        ICD10  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 1  2018-11-14 00:00:00        ICD10  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 2  2014-04-03 00:00:00        ICD10  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 3  2014-04-03 00:00:00        ICD10  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 4  2014-04-03 00:00:00        ICD10  b8d4e6bd-e1b7-4a36-8df1-911926190d53

# %% [markdown]
# #### Merge data sources

# %%
df_problems_merged = pd.concat([df_problems_r3, df_dx_r3, df_dx_registry])
df_problems_merged.head()
# Out:
#   DX_CODE_TYPE  DX_CODE                                            DX_NAME  \
# 0         ICD9   535.50  Unspecified gastritis and gastroduodenitis wit...
# 1         ICD9    578.1                                     Blood in stool
# 2         ICD9    555.2  Regional enteritis of small intestine with lar...
# 3        ICD10    H26.9                                           Cataract
# 4        ICD10  H04.129                                            Dry eye
#
#       DX_DATE                    PROJECT_PATIENT_ID
# 0  11/15/2011  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1  10/10/2011  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2  04/04/2012  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  06/20/2016  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  06/20/2016  64a0ac31-091d-45c5-86e3-86516ee4299a

# %%
# standardize code types
df_problems_merged['DX_CODE_TYPE'].unique()
# Out:
# array(['ICD9', 'ICD10', 'ICD9CM', 'ICD10CM', nan], dtype=object)

# %%
df_problems_merged['DX_CODE_TYPE'] = df_problems_merged['DX_CODE_TYPE'].str.replace('CM', '')
df_problems_merged['DX_CODE_TYPE'].unique()
# Out:
# array(['ICD9', 'ICD10', nan], dtype=object)

# %%
df_problems_merged[df_problems_merged['DX_CODE_TYPE'].isna()].shape
# Out:
# (24, 5)

# %% [markdown]
# **TODO**: 24 without a dx code type. remove these?

# %%
df_problems_merged = df_problems_merged[df_problems_merged['DX_CODE_TYPE'].notna()]
len(df_problems_merged)
# Out:
# 506038

# %% [markdown]
# #### Write out

# %%
df_problems_merged.to_csv(f'{data_out_path}problem_list_merged.csv')

# %% [markdown]
# ### Procedures

# %% [markdown]
# #### R3

# %%
df_procedures_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_PROCS_2020_05_12.csv')
df_procedures_r3.head()
# Out:
#      STUDY_ID      VISIT_ID  ORDER_PROC_ID   PROC_DATE PROC_CODE  PROC_TYPE  \
# 0  6999994666  4.529024e+08     74962671.0         NaN     71260     CUSTOM
# 1  6999994666  4.529024e+08     74962676.0         NaN     74160     CPT(R)
# 2  6999994666  4.503987e+08     74962677.0         NaN     43235     CPT(R)
# 3  6999994666  5.210964e+12            NaN  02/06/2018     29823  CPT/HCPCS
# 4  6999994666  5.210964e+12            NaN  02/06/2018     29827  CPT/HCPCS
#
#                                            PROC_NAME PROC_LOCATION  ORDER_DATE
# 0                             CT CHEST WITH CONTRAST           NaN  09/21/2011
# 1                           CT ABDOMEN WITH CONTRAST           NaN  10/01/2011
# 2                       UPPER GI ENDOSCOPY,DIAGNOSIS           NaN  10/10/2011
# 3  Arthroscopy, shoulder, surgical; debridement, ...            OR         NaN
# 4  Arthroscopy, shoulder, surgical; with rotator ...            OR         NaN

# %%
df_procedures_r3 = df_procedures_r3[['STUDY_ID', 'PROC_CODE',  'PROC_NAME', 'ORDER_DATE', 'PROC_DATE']]
df_procedures_r3 = merge_project_patient_id(df_procedures_r3, df_patients_merged, 'r3')
df_procedures_r3.head()
# Out:
#   PROC_CODE                                          PROC_NAME  ORDER_DATE  \
# 0     71260                             CT CHEST WITH CONTRAST  09/21/2011
# 1     74160                           CT ABDOMEN WITH CONTRAST  10/01/2011
# 2     43235                       UPPER GI ENDOSCOPY,DIAGNOSIS  10/10/2011
# 3     29823  Arthroscopy, shoulder, surgical; debridement, ...         NaN
# 4     29827  Arthroscopy, shoulder, surgical; with rotator ...         NaN
#
#     PROC_DATE                    PROJECT_PATIENT_ID
# 0         NaN  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1         NaN  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2         NaN  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  02/06/2018  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  02/06/2018  64a0ac31-091d-45c5-86e3-86516ee4299a

# %% [markdown]
# #### Registry

# %%
df_procedures_registry = pd.read_excel(f'{data_in_registry_path}deid_IBD_Registry_BA1951_Rad_Diagnostic_Tests_2020-01-05-12-18-06.xlsx')
print(df_procedures_registry.shape)
df_procedures_registry.head()
# Out:
# (342232, 20)
#    Unnamed: 0  AUTO_ID  VISIT DEPT           VISIT_DATE        ORDERING_DATE  \
# 0           0        2         NaN  2009-07-23 00:00:00  2009-07-23 00:00:00
# 1           1        2         NaN  2010-03-17 00:00:00  2010-03-17 00:00:00
# 2           2       95         NaN  2009-10-05 00:00:00  2009-10-05 00:00:00
# 3           3      108         NaN  2010-02-02 00:00:00  2010-02-02 00:00:00
# 4           4      123         NaN  2009-04-28 00:00:00  2009-04-28 00:00:00
#
#   CPT_CODE                 DESCRIPTION  QUANTITY PROC_START_DATE PAT_STATUS  \
# 0  7699905     GI ENDOSCOPIC PROCEDURE         1             NaN      Alive
# 1  7699905     GI ENDOSCOPIC PROCEDURE         1             NaN      Alive
# 2  7699905     GI ENDOSCOPIC PROCEDURE         1             NaN      Alive
# 3    93005  ELECTROCARDIOGRAM, TRACING         1             NaN      Alive
# 4    93005  ELECTROCARDIOGRAM, TRACING         1             NaN      Alive
#
#   PROC_CAT_NAME     ORDER_TYPE ORDER_CLASS ORDER_STATUS          UPDATE_DATE  \
# 0    PROCEDURES  GI PROCEDURES         NaN    Completed  2015-11-17 15:34:00
# 1    PROCEDURES  GI PROCEDURES         NaN    Completed  2015-11-25 11:25:00
# 2    PROCEDURES  GI PROCEDURES         NaN    Completed  2015-11-19 15:29:00
# 3      MEDICINE            EKG         NaN    Completed  2015-11-24 09:19:00
# 4      MEDICINE            EKG         NaN    Completed  2015-11-13 12:54:00
#
#           AUTH_PROV_NAME          RESULT_DATE REVIEW_DATE CENTER STUDY_RESULT
# 0  BELLICINI, NICHOLAS A  2009-09-03 15:27:00         NaN    NaN          NaN
# 1      GLORIOSO, DAVID V  2010-03-17 09:52:00         NaN    NaN          NaN
# 2       LIMAURO, DAVID L  2009-10-05 14:54:00         NaN    NaN          NaN
# 3   HANDELSMAN, GORDON L  2010-02-02 07:45:00         NaN    NaN          NaN
# 4      JACOBS, RICHARD P  2009-04-28 22:55:00         NaN    NaN          NaN

# %%
df_procedures_registry = df_procedures_registry[['AUTO_ID', 'CPT_CODE', 'DESCRIPTION', 'VISIT_DATE', 'PROC_START_DATE']]
df_procedures_registry.rename(columns={
    'CPT_CODE': 'PROC_CODE',
    'DESCRIPTION': 'PROC_NAME',
    'VISIT_DATE': 'ORDER_DATE',
    'PROC_START_DATE': 'PROC_DATE'
}, inplace=True)
df_procedures_registry = merge_project_patient_id(df_procedures_registry, df_patients_merged, 'registry')
df_procedures_registry.head()
# Out:
#   PROC_CODE                   PROC_NAME           ORDER_DATE PROC_DATE  \
# 0   7699905     GI ENDOSCOPIC PROCEDURE  2009-07-23 00:00:00       NaN
# 1   7699905     GI ENDOSCOPIC PROCEDURE  2010-03-17 00:00:00       NaN
# 2   7699905     GI ENDOSCOPIC PROCEDURE  2009-10-05 00:00:00       NaN
# 3     93005  ELECTROCARDIOGRAM, TRACING  2010-02-02 00:00:00       NaN
# 4     93005  ELECTROCARDIOGRAM, TRACING  2009-04-28 00:00:00       NaN
#
#                      PROJECT_PATIENT_ID
# 0  865adc34-4b87-4747-b192-dc7301c6f362
# 1  865adc34-4b87-4747-b192-dc7301c6f362
# 2  9006db1e-95f2-4d04-847d-2257d0c4a214
# 3  05bd182a-6b98-4c29-9a48-d3e6335344c6
# 4  48949aa3-ef57-406d-b545-1ca8b6796285

# %% [markdown]
# #### Merge data sources

# %%
df_procedures_merged = df_procedures_r3.append(df_procedures_registry)
print(df_procedures_merged.shape)
df_procedures_merged.head()
# Out:
# (503497, 5)
#   PROC_CODE                                          PROC_NAME  ORDER_DATE  \
# 0     71260                             CT CHEST WITH CONTRAST  09/21/2011
# 1     74160                           CT ABDOMEN WITH CONTRAST  10/01/2011
# 2     43235                       UPPER GI ENDOSCOPY,DIAGNOSIS  10/10/2011
# 3     29823  Arthroscopy, shoulder, surgical; debridement, ...         NaN
# 4     29827  Arthroscopy, shoulder, surgical; with rotator ...         NaN
#
#     PROC_DATE                    PROJECT_PATIENT_ID
# 0         NaN  64a0ac31-091d-45c5-86e3-86516ee4299a
# 1         NaN  64a0ac31-091d-45c5-86e3-86516ee4299a
# 2         NaN  64a0ac31-091d-45c5-86e3-86516ee4299a
# 3  02/06/2018  64a0ac31-091d-45c5-86e3-86516ee4299a
# 4  02/06/2018  64a0ac31-091d-45c5-86e3-86516ee4299a

# %%
df_procedures_merged[df_procedures_merged['PROJECT_PATIENT_ID'].isna()].shape
# Out:
# (0, 5)

# %% [markdown]
# #### Cleanup

# %%
df_procedures_merged['PROC_NAME'] = df_procedures_merged['PROC_NAME'].str.upper()

# %% [markdown]
# **TODO: CONFIRM** Screening for only a few kinds of procedures (as long as `PROC_NAME` contains this string, it counts):

# %%
def proc_list_filter(x):
    for item in ['MR CHOLANG', 'CT ABD', 'CT PELVIS', 'CT ABDOMEN']:
        if item in str(x['PROC_NAME']):
            return True
        
    return False

df_procedures_merged = df_procedures_merged[df_procedures_merged.apply(proc_list_filter, axis='columns')]
print(df_procedures_merged.shape)
# Out:
# (21561, 5)

# %% [markdown]
# **TODO:**
# - Do the (OO) suffix or the NM prefix make distinct cases?
# - Is ABDOMEN/PELVIS different from ABDOMEN AND PELVIS?
# - IN NUCLEAR MED important?

# %%
sorted(df_procedures_merged['PROC_NAME'].unique())
# Out:
# ['CT ABD AND PELVIS WITH CONTRAST PANEL',
#  'CT ABD AND PELVIS WITHOUT CONTRAST PANEL',
#  'CT ABD WITH CT LOWER EXTREMITIES',
#  'CT ABD/PELVIS W/O CONTRAST NC',
#  'CT ABDOMEN AND PELVIS WITH AND WITHOUT CONTRAST',
#  'CT ABDOMEN AND PELVIS WITH CONTRAST',
#  'CT ABDOMEN AND PELVIS WITHOUT CONTRAST',
#  'CT ABDOMEN W/CONTRST',
#  'CT ABDOMEN WITH  & WITHOUT  CONTRAST',
#  'CT ABDOMEN WITH AND WITHOUT CONTRAST',
#  'CT ABDOMEN WITH AND WITHOUT CONTRAST (OO)',
#  'CT ABDOMEN WITH CONTRAST',
#  'CT ABDOMEN WITHOUT CONTRAST',
#  'CT ABDOMEN WITHOUT CONTRAST (OO)',
#  'CT ABDOMEN/PELVIS WITH CONTRAST DONE IN NUCLEAR MED',
#  'CT ABDOMEN/PELVIS WITHOUT CONTRAST DONE IN NUC MED',
#  'CT PELVIS WITH  & WITHOUT  CONTRAST',
#  'CT PELVIS WITH AND WITHOUT CONTRAST',
#  'CT PELVIS WITH AND WITHOUT CONTRAST (OO)',
#  'CT PELVIS WITH CONTRAST',
#  'CT PELVIS WITH CONTRAST (OO)',
#  'CT PELVIS WITHOUT  CONTRAST',
#  'CT PELVIS WITHOUT CONTRAST',
#  'CT PELVIS WITHOUT CONTRAST (OO)',
#  'MR CHOLANGIOPANCREATOGRAPHY (MRCP)',
#  'NM CT ABDOMEN WITH CONTRAST',
#  'NM CT ABDOMEN WITHOUT CONTRAST']

# %%
df_procedures_merged['PROC_NAME'] = df_procedures_merged['PROC_NAME'].replace('CT ABDOMEN WITH  & WITHOUT  CONTRAST', 'CT ABDOMEN WITH AND WITHOUT CONTRAST')
df_procedures_merged['PROC_NAME'] = df_procedures_merged['PROC_NAME'].replace('CT ABDOMEN W/CONTRST', 'CT ABDOMEN WITH CONTRAST')
df_procedures_merged['PROC_NAME'] = df_procedures_merged['PROC_NAME'].replace('CT PELVIS WITH  & WITHOUT  CONTRAST', 'CT PELVIS WITH AND WITHOUT CONTRAST')
sorted(df_procedures_merged['PROC_NAME'].unique())
# Out:
# ['CT ABD AND PELVIS WITH CONTRAST PANEL',
#  'CT ABD AND PELVIS WITHOUT CONTRAST PANEL',
#  'CT ABD WITH CT LOWER EXTREMITIES',
#  'CT ABD/PELVIS W/O CONTRAST NC',
#  'CT ABDOMEN AND PELVIS WITH AND WITHOUT CONTRAST',
#  'CT ABDOMEN AND PELVIS WITH CONTRAST',
#  'CT ABDOMEN AND PELVIS WITHOUT CONTRAST',
#  'CT ABDOMEN WITH AND WITHOUT CONTRAST',
#  'CT ABDOMEN WITH AND WITHOUT CONTRAST (OO)',
#  'CT ABDOMEN WITH CONTRAST',
#  'CT ABDOMEN WITHOUT CONTRAST',
#  'CT ABDOMEN WITHOUT CONTRAST (OO)',
#  'CT ABDOMEN/PELVIS WITH CONTRAST DONE IN NUCLEAR MED',
#  'CT ABDOMEN/PELVIS WITHOUT CONTRAST DONE IN NUC MED',
#  'CT PELVIS WITH AND WITHOUT CONTRAST',
#  'CT PELVIS WITH AND WITHOUT CONTRAST (OO)',
#  'CT PELVIS WITH CONTRAST',
#  'CT PELVIS WITH CONTRAST (OO)',
#  'CT PELVIS WITHOUT  CONTRAST',
#  'CT PELVIS WITHOUT CONTRAST',
#  'CT PELVIS WITHOUT CONTRAST (OO)',
#  'MR CHOLANGIOPANCREATOGRAPHY (MRCP)',
#  'NM CT ABDOMEN WITH CONTRAST',
#  'NM CT ABDOMEN WITHOUT CONTRAST']

# %% [markdown]
# #### Write out

# %%
df_procedures_merged.to_csv(f'{data_out_path}procedures_merged.csv')

# %% [markdown]
# ### Hospitalizations & ER visits

# %% [markdown]
# #### R3

# %% [markdown]
# We also read the hospitalizations/ER visits from the encounters file, but this time we don't restrict them by department (presumably because they might not fall under the departments we filter by when we pull in encounters above).

# %%
df_hosper_r3 = pd.read_csv(f'{data_in_r3_path}R3_1646_BINION_ENCOUNTERS_2020_05_12.csv')
df_hosper_r3.head()
# Out:
#      STUDY_ID   VISIT_ID           START_DATE END_DATE      ENC_TYPE  \
# 0  6999994666  452902438  09/21/2011 00:00:00      NaN  OFFICE VISIT
# 1  6999994666  450398659  10/10/2011 00:00:00      NaN  OFFICE VISIT
# 2  6999994666  452908020  09/07/2011 00:00:00      NaN     TELEPHONE
# 3  6999994666  452509743  09/12/2011 00:00:00      NaN   APPOINTMENT
# 4  6999994666  451199413  09/21/2011 00:00:00      NaN       HISTORY
#
#             LOCATION APPT_STATUS ADMIT_SOURCE HOSPITAL_SERVICE PATIENT_TYPE  \
# 0     PIMA GREENTREE   COMPLETED          NaN              NaN          NaN
# 1  RAVI GI GREENTREE   COMPLETED          NaN              NaN          NaN
# 2     PIMA GREENTREE         NaN          NaN              NaN          NaN
# 3     PIMA GREENTREE    CANCELED          NaN              NaN          NaN
# 4     PIMA GREENTREE         NaN          NaN              NaN          NaN
#
#   PATIENT_CLASS CHIEF_COMPLAINT CHIEF_COMPLAINT_ONSET_DATE
# 0           NaN             NaN                        NaN
# 1           NaN             NaN                        NaN
# 2           NaN             NaN                        NaN
# 3           NaN             NaN                        NaN
# 4           NaN             NaN                        NaN

# %%
# drop unnecessary columns
df_hosper_r3 = df_hosper_r3[[
    'STUDY_ID',
    'START_DATE',
    'ENC_TYPE'
]]

# rename columns
df_hosper_r3.rename(columns={'START_DATE': 'CONTACT_DATE'}, inplace=True)

# filter encounter types of interest
df_hosper_r3 = df_hosper_r3[(df_hosper_r3['ENC_TYPE'] == 'DISCHARGE SUMMARY') | (df_hosper_r3['ENC_TYPE'] == 'ER REPORT')]
df_hosper_r3['IS_HOSPITALIZATION'] = df_hosper_r3['ENC_TYPE'].apply(lambda x: 1 if x == 'DISCHARGE SUMMARY' else 0)
df_hosper_r3['IS_ER_VISIT'] = df_hosper_r3['ENC_TYPE'].apply(lambda x: 1 if x == 'ER REPORT' else 0)
df_hosper_r3.drop(columns=['ENC_TYPE'], inplace=True)
df_hosper_r3 = merge_project_patient_id(df_hosper_r3, df_patients_merged, 'r3')
df_hosper_r3.head()
# Out:
#           CONTACT_DATE  IS_HOSPITALIZATION  IS_ER_VISIT  \
# 0  07/31/2011 00:00:00                   0            1
# 1  02/18/2011 00:00:00                   0            1
# 2  08/14/2011 00:00:00                   1            0
# 3  07/21/2011 00:00:00                   1            0
# 4  12/08/2012 00:00:00                   0            1
#
#                      PROJECT_PATIENT_ID
# 0  683be0ab-8f8c-44c5-8024-b5f660ca3e9b
# 1  b807eb20-ef60-4c6a-899c-bb033fa6339e
# 2  c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 3  c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 4  f8a58e23-0822-4dc8-bda3-82fedc214e5c

# %% [markdown]
# #### Registry

# %% [markdown]
# This logic is directly taken from our old merge logic (`merge_registry_with_r3.ipynb`), but I include it here so our current logic is all in one place (and so I can produce the file with `PROJECT_PATIENT_ID`s instead of `AUTO_ID`s).

# %% [markdown]
# **TODO**: If I'm understanding the old merge logic correctly, we don't have this data for R3 patients. This seems like a big liability for our model.

# %%
df_hosper_registry = pd.read_excel(f'{data_in_registry_path}deid_IBD_Registry_BA1951_ER_OP_DC_Reports_2020-01-05-09-11-16.xls')
df_hosper_registry.head()
# Out:
#    Unnamed: 0  AUTO_ID  ENC_TYPE_C ENC_TYPE_NAME         CONTACT_DATE  \
# 0           0        0         203     OP Report  2010-01-06 00:00:00
# 1           1        0         203     OP Report  2010-04-07 00:00:00
# 2           2        0         203     OP Report  2010-08-04 00:00:00
# 3           3        0         203     OP Report  2018-04-20 00:00:00
# 4           4        1         203     OP Report  2009-03-19 00:00:00
#
#       DEPT_ID            DEPT_NAME
# 0         NaN                  NaN
# 1  11116101.0       XBEDFORD ORTHO
# 2         NaN                  NaN
# 3      9999.0  EXTERNAL DEPARTMENT
# 4      9999.0  EXTERNAL DEPARTMENT

# %%
df_hosper_registry = df_hosper_registry[[
    'AUTO_ID',
    'ENC_TYPE_NAME',
    'CONTACT_DATE'
]]

df = df_hosper_registry.groupby(['AUTO_ID','CONTACT_DATE']).size().reset_index().rename(columns={0:'count'})
df['ER'] = 0
df['DS'] = 0
df['OP'] = 0

for idx, row in df.iterrows():
    q = 'AUTO_ID == ' + str(row['AUTO_ID']) + ' and CONTACT_DATE == "' + row['CONTACT_DATE'] + '"'
    temp = df_hosper_registry.query(q)
    enc_type_counts = temp['ENC_TYPE_NAME'].value_counts().to_dict()
    if 'OP Report' in enc_type_counts.keys():
        df.at[idx, 'OP'] = enc_type_counts['OP Report']
    if 'Discharge Summary' in enc_type_counts.keys():
        df.at[idx, 'DS'] = enc_type_counts['Discharge Summary']
    if 'ER Report' in enc_type_counts.keys():
        df.at[idx, 'ER'] = enc_type_counts['ER Report']
        
df['HOSP'] = 0
df['ER_VISITS'] = 0

for idx, row in df.iterrows():
    hosp = row['DS'] - row['ER']
    er = 0
    if hosp < 0:
        hosp = 0
    if row['ER'] != 0:
        er = 1
    
    df.at[idx, 'HOSP'] = hosp
    df.at[idx, 'ER_VISITS'] = er
    
# drop unnecessary columns
df = df[['AUTO_ID', 'CONTACT_DATE', 'HOSP', 'ER_VISITS']]
df.rename(columns={ 'HOSP': 'IS_HOSPITALIZATION', 'ER_VISITS': 'IS_ER_VISIT' }, inplace=True)

# merge project patient id
df = merge_project_patient_id(df, df_patients_merged, 'registry')
df.head()
# Out:
#           CONTACT_DATE  IS_HOSPITALIZATION  IS_ER_VISIT  \
# 0  2010-01-06 00:00:00                   0            0
# 1  2010-04-07 00:00:00                   0            0
# 2  2010-08-04 00:00:00                   0            0
# 3  2018-04-20 00:00:00                   0            0
# 4  2009-03-17 00:00:00                   0            1
#
#                      PROJECT_PATIENT_ID
# 0  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 1  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 2  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 3  b8d4e6bd-e1b7-4a36-8df1-911926190d53
# 4  a9c3cee8-9f41-47cb-8f0d-af62ef0f31f9

# %% [markdown]
# #### Merge data sources

# %%
df_hosper_merged = df_hosper_r3.append(df)
df_hosper_merged.head()
# Out:
#           CONTACT_DATE  IS_HOSPITALIZATION  IS_ER_VISIT  \
# 0  07/31/2011 00:00:00                   0            1
# 1  02/18/2011 00:00:00                   0            1
# 2  08/14/2011 00:00:00                   1            0
# 3  07/21/2011 00:00:00                   1            0
# 4  12/08/2012 00:00:00                   0            1
#
#                      PROJECT_PATIENT_ID
# 0  683be0ab-8f8c-44c5-8024-b5f660ca3e9b
# 1  b807eb20-ef60-4c6a-899c-bb033fa6339e
# 2  c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 3  c1c79322-d705-43c5-b5d2-d17689bbb5a9
# 4  f8a58e23-0822-4dc8-bda3-82fedc214e5c

# %% [markdown]
# #### Write out

# %%
df_hosper_merged.to_csv(f'{data_out_path}hospitalizations_and_er_visits_merged.csv')
